# %%
import tensorflow as tf

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train.shape

# %%
import matplotlib.pylab as plt

# %%
import random
index = random.randint(0, 6000)
plt.imshow(x_train[index].reshape(28, 28))

# %%
x_train = x_train/255
x_test = x_test/255

# %% [markdown]
# Creation of CNN model

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
cnn = Sequential()
cnn.add(Flatten(input_shape=(28, 28)))
cnn.add(Dense(128, activation='relu'))
cnn.add(Dense(10, activation='softmax'))

# %%
cnn.summary()

# %%
cnn.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = cnn.fit(x_train, y_train, epochs=25, validation_split=.2 )

# %%
y_prob = cnn.predict(x_test)
y_predict = y_prob.argmax(axis=1)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_predict)
accuracy

# %%
x_train[0]

# %%
idx = random.randint(0, 6000)
plt.imshow(x_train[idx])

# %%
cnn.predict(x_train[idx].reshape(1, 28, 28)).argmax(axis=1)

# %%
plt.plot(history.history['val_loss'])
plt.plot(history.history['loss'])

# %%
plt.plot(history.history['accuracy'])
